# %% [markdown]
# ### Data Drift Evidently AI

# %%
print("active")
# Out:
# active

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection

# %% [markdown]
# ### Load Boston dataset
#
# - data_url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
# - boston_frame = pd.read_csv(data_url)

# %% [markdown]
# ### For wine dataset

# %%
from sklearn.datasets import load_wine

wine_data = load_wine()

print(wine_data.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
wine_frame = pd.DataFrame(wine_data.data, columns=wine_data.feature_names)
#wine is a the dataframe df containing wine data
wine_frame.head()
# Out:
#    alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %%
wine_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# ### Data Drift Dashboard

# %%
wine_frame.shape
# Out:
# (178, 13)

# %%
wine_frame[:140] # train / reference data
# Out:
#      alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0      14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1      13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2      13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3      14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4      13.24        2.59  2.87  ...  1.04                          2.93    735.0
# ..       ...         ...   ...  ...   ...                           ...      ...
# 135    12.60        2.46  2.20  ...  0.73                          1.58    695.0
# 136    12.25        4.72  2.54  ...  0.75                          1.27    720.0
# 137    12.53        5.51  2.64  ...  0.82                          1.69    515.0
# 138    13.49        3.59  2.19  ...  0.81                          1.82    580.0
# 139    12.84        2.96  2.61  ...  0.89                          2.15    590.0
#
# ...

# %%
wine_frame[140:] # test data
# Out:
#      alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 140    12.93        2.81  2.70  ...  0.77                          2.31    600.0
# 141    13.36        2.56  2.35  ...  0.70                          2.47    780.0
# 142    13.52        3.17  2.72  ...  0.89                          2.06    520.0
# 143    13.62        4.95  2.35  ...  0.91                          2.05    550.0
# 144    12.25        3.88  2.20  ...  0.65                          2.00    855.0
# 145    13.16        3.57  2.15  ...  0.60                          1.68    830.0
# 146    13.88        5.04  2.23  ...  0.58                          1.33    415.0
# 147    12.87        4.61  2.48  ...  0.54                          1.86    625.0
# 148    13.32        3.24  2.38  ...  0.55                          1.62    650.0
# 149    13.08        3.90  2.36  ...  0.57                          1.33    550.0
# 150    13.50        3.12  2.62  ...  0.59                          1.30    500.0
# ...

# %%
wine_data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])

# %%
wine_data_drift_dashboard.calculate(wine_frame[:140], wine_frame[140:])

# %%
wine_data_drift_dashboard.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
# ...

# %%
wine_data_drift_dashboard.save("wine_data_drift_report.html")

# %%
wine_data_drift_profile = Profile(sections=[DataDriftProfileSection()])

# %%
wine_data_drift_profile.calculate(wine_frame[:140], wine_frame[140:])

# %%
wine_data_drift_profile.json()
# Out:
# '{"data_drift": {"name": "data_drift", "datetime": "2024-10-22 15:50:43.488292", "data": {"utility_columns": {"date": null, "id": null, "target": null, "prediction": null}, "num_feature_names": ["alcalinity_of_ash", "alcohol", "ash", "color_intensity", "flavanoids", "hue", "magnesium", "malic_acid", "nonflavanoid_phenols", "od280/od315_of_diluted_wines", "proanthocyanins", "proline", "total_phenols"], "cat_feature_names": [], "text_feature_names": [], "datetime_feature_names": [], "target_names": null, "options": {"confidence": null, "drift_share": 0.5, "nbinsx": 10, "xbins": null}, "metrics": {"n_features": 13, "n_drifted_features": 12, "share_drifted_features": 0.9230769230769231, "dataset_drift": true, "alcalinity_of_ash": {"current_small_hist": {"x": [18.5, 19.35, 20.2, 21.05, 21.9, 22.75, 23.6, 24.45, 25.3, 26.15, 27.0], "y": [0.12383900928792549, 0.3405572755417965, 0.12383900928792549, 0.0928792569659445, 0.18575851393188825, 0.09287925696594412, 0.0309597523219815, 0.12383900
# ...
